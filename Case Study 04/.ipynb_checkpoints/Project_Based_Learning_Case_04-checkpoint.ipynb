# %% [markdown]
# # CASE 04 -  Stock Price Prediction

# %% [markdown]
# Pada studi kasus ini, kamu akan berlatih melakukan pengembangan model yang dapat menebak harga
# saham dari data yang tersedia (misalnya ingin menebak harga saham dari mulai Januari 2016 - Desember
# 2017, atau tahun 2017 saja). Kamu bisa lakukan modeling ANN menggunakan RNN!
# Lebih lengkapnya, lakukanlah beberapa langkah berikut ini:
# 1. Lakukan import libraries & data, EDA dan juga preprocessing. Berikut ini beberapa tahapan:
# - Import libraries & dataset
# - Function preparation (prediction plot, RMSE evaluation, etc.)
# - Missing values handling
# - Splitting data training & testing
# - Data plot visualization
# - Feature scaling for data train
# - Data structure & reshaping
# 2. Tentukan teknik RNN yang cocok untuk tahap modeling dan lakukan persiapan untuk data test
# 3. Jalankan prediction dan buat visualisasi data dari hasil test yang telah dilakukan
# 4. Berikan kesimpulan dan insight, serta evaluasi model yang kamu buat

# %% [markdown]
# ## Langkah 1: Import Libraries & Data, EDA, dan Preprocessing

# %%
# Importing the libraries, fill the import name libraries below
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf


#Import keras libraries that you need
from keras.models import Sequential
from keras.layers import Dense, Activation
import math
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# Import Dataset
data = pd.read_csv(r"C:\Users\Acer\Kelas Work_Project Data Science\Case Study 04\all_stocks_2017-01-01_to_2018-01-01.csv")
data
# Out:
#             Date    Open    High     Low   Close    Volume  Name
# 0     2017-01-03  178.83  180.00  177.22  178.05   2510055   MMM
# 1     2017-01-04  178.03  178.90  177.61  178.32   1541985   MMM
# 2     2017-01-05  178.26  179.14  176.89  177.71   1447848   MMM
# 3     2017-01-06  177.29  178.60  175.80  178.23   1625049   MMM
# 4     2017-01-09  178.37  178.38  177.20  177.27   1622625   MMM
# ...          ...     ...     ...     ...     ...       ...   ...
# 7776  2017-12-22   71.42   71.87   71.22   71.58  10979165  AABA
# 7777  2017-12-26   70.94   71.39   69.63   69.86   8542802  AABA
# 7778  2017-12-27   69.77   70.49   69.69   70.06   6345124  AABA
# 7779  2017-12-28   70.12   70.32   69.51   69.82   7556877  AABA
# 7780  2017-12-29   69.79   70.13   69.43   69.85   6613070  AABA
#
# [7781 rows x 7 columns]

# %%
# EDA - Display Basic Info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3019 entries, 0 to 3019
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3019 non-null   object
#  1   Open    3019 non-null   float64
#  2   High    3019 non-null   float64
#  3   Low     3019 non-null   float64
#  4   Close   3019 non-null   float64
#  5   Volume  3019 non-null   int64
#  6   Name    3019 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 188.7+ KB
# None

# %%
# Missing Values Handling (if any)
df.dropna(inplace=True)

# %%
# Splitting Data Training & Testing
train_size = int(len(df) * 0.8)
train_data, test_data = df[:train_size], df[train_size:]

# %%
# Data Plot Visualization
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Closing Price')
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %% [markdown]
# #### PENJELASAN
# Dapat dilihat bahwa grafik harga saham yang naik turun naik turun biasanya mencerminkan volatilitas pasar. Ketika kita melihat grafik ini, kita dapat melihat bahwa harga saham mengalami fluktuasi yang signifikan dari waktu ke waktu.
#
# Misalnya, pada suatu periode tertentu, grafik mungkin menunjukkan bahwa harga saham meningkat, menandakan adanya tren naik. Ini bisa disebabkan oleh faktor-faktor seperti pertumbuhan perusahaan, kinerja industri yang kuat, atau berita positif di sektor tertentu. Investor dapat melihat peluang untuk mendapatkan keuntungan selama periode tersebut.
#
# Namun, kemudian kita mungkin melihat bahwa harga saham turun tajam, menandakan perubahan sentimen pasar. Hal ini bisa dipicu oleh berita buruk, kondisi makroekonomi yang memburuk, atau faktor lain yang memengaruhi pasar secara negatif. Investor yang cerdas mungkin mulai berhati-hati dan mempertimbangkan strategi risk management.

# %%
# Feature Scaling for Data Train
scaler = MinMaxScaler()
train_data_scaled = scaler.fit_transform(train_data['Close'].values.reshape(-1, 1))

# %%
# Data Structure & Reshaping for RNN
X_train, y_train = [], []
for i in range(60, len(train_data_scaled)):
    X_train.append(train_data_scaled[i-60:i, 0])
    y_train.append(train_data_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ## Langkah 2 : Menentukan Teknik RNN dan Mempersiapkan Data Test

# %%
# Model Initialization
model = Sequential()
model.add(SimpleRNN(units=50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Training the Model
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 74/74 [==============================] - 4s 19ms/step - loss: 0.0211
# Epoch 2/10
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0010
# Epoch 3/10
# 74/74 [==============================] - 1s 19ms/step - loss: 9.8610e-04
# Epoch 4/10
# 74/74 [==============================] - 1s 18ms/step - loss: 9.1404e-04
# Epoch 5/10
# 74/74 [==============================] - 1s 18ms/step - loss: 8.0545e-04
# Epoch 6/10
# 74/74 [==============================] - 1s 15ms/step - loss: 7.6549e-04
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 7.2779e-04
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 7.2707e-04
# Epoch 9/10
# 74/74 [==============================] - 1s 18ms/step - loss: 6.9942e-04
# Epoch 10/10
# 74/74 [==============================] - 2s 22ms/step - loss: 6.9121e-04

# %%
# Prepare Test Data
test_data_scaled = scaler.transform(test_data['Close'].values.reshape(-1, 1))

X_test, y_test = [], []
for i in range(60, len(test_data_scaled)):
    X_test.append(test_data_scaled[i-60:i, 0])
    y_test.append(test_data_scaled[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Langkah 3 : Menjalankan Prediksi dan Membuat Visualisasi Data Hasil Test

# %%
# Make Predictions
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 17/17 [==============================] - 1s 14ms/step

# %%
# Visualize Results
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['Close'], color='red', label='Actual Stock Price')
plt.plot(test_data['Date'][60:], predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# #### PENJELASAN
# * Grafik menampilkan dua garis utama, yaitu garis merah dan biru.
# * Garis merah mencerminkan harga saham aktual dari waktu ke waktu.
# * Garis biru menggambarkan prediksi harga saham yang dihasilkan oleh model.
# * Terlihat bahwa garis biru mengikuti dengan cermat tren dan fluktuasi harga yang ditunjukkan oleh garis merah.
# * Kesamaan pola antara kedua garis menunjukkan kemampuan model dalam memprediksi perubahan harga saham.
# * Secara umum, grafik menciptakan gambaran visual tentang dinamika naik turun harga saham selama periode tertentu.

# %% [markdown]
# ## Langkah 4 : Kesimpulan dan Evaluasi Model
#
# Setelah menjalankan model, lihat visualisasi hasil prediksi dan bandingkan dengan harga saham aktual. Evaluasi model dapat dilakukan dengan menggunakan metrik seperti Root Mean Squared Error (RMSE):

# %%
# RMSE Evaluation
rmse = np.sqrt(mean_squared_error(test_data['Close'][60:], predicted_stock_price))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.9280115401367702

# %% [markdown]
# #### PENJELASAN
# Dengan nilai Root Mean Squared Error (RMSE) sebesar 0.93, dapat disimpulkan bahwa model memiliki tingkat akurasi yang cukup baik dalam memprediksi harga saham berdasarkan data historis yang digunakan.
#
# Kesimpulan lainnya dapat mencakup:
#
# * Model RNN yang telah dibangun mampu menangkap tren dan fluktuasi dalam harga saham.
# * Peningkatan atau penurunan signifikan dalam harga saham dapat diprediksi dengan baik oleh model.
# * Penggunaan data historis dalam rentang waktu tertentu memberikan hasil yang memuaskan.
